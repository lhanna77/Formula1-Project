# %% [markdown]
# #### Access dataframes using SQL
# ##### Objectives
# 1. Create temporary views on dataframes
# 2. Access the view from SQL cell
# 3. Access the view from Python cell

# %%
# %run configuration
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 4, Finished, Available)

# %%
race_results_df = spark.read.parquet(f"{silver_folder_path}/race_results")
display(race_results_df)
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, b38b15c9-2f17-473b-ad47-3b05f1c88158)

# %%
race_results_df.createOrReplaceTempView("v_race_results")
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 6, Finished, Available)

# %%
# %%sql
# SELECT COUNT(1)
# FROM v_race_results
# WHERE race_year = 2020
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 7, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
p_race_year = 2019
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 8, Finished, Available)

# %%
race_results_2019_df = spark.sql(f"SELECT * FROM v_race_results WHERE race_year = {p_race_year}")
display(race_results_2019_df)
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 10, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 3edff5ba-ea2d-4932-be07-8adecb51c5b8)

# %% [markdown]
# ##### Global Temporary Views
# 1. Create global temporary views on dataframes
# 2. Access the view from SQL cell
# 3. Access the view from Python cell
# 4. Acesss the view from another notebook

# %%
race_results_df.createOrReplaceGlobalTempView("gv_race_results")
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 11, Finished, Available)

# %%
# %%sql
# SHOW TABLES IN global_temp;
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 13, Finished, Available)
# <Spark SQL result set with 2 rows and 3 fields>

# %%
# %%sql
# SELECT *
#   FROM global_temp.gv_race_results;
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 14, Finished, Available)
# <Spark SQL result set with 1000 rows and 14 fields>

# %%
spark.sql("SELECT * FROM global_temp.gv_race_results").show()
# Out:
# StatementMeta(, 6212f03c-dd1a-4409-af32-1b8078355c75, 15, Finished, Available)
# +---------+--------------------+---------+----------------+--------------------+-------------+------------------+--------+----+-----------+-----------+------+--------+--------------------+
# |race_year|           race_name|race_date|circuit_location|         driver_name|driver_number|driver_nationality|    team|grid|fastest_lap|  race_time|points|position|        created_date|
# +---------+--------------------+---------+----------------+--------------------+-------------+------------------+--------+----+-----------+-----------+------+--------+--------------------+
# |     2004|Australian Grand ...|     null|       Melbourne|  Juan Pablo Montoya|         null|         Colombian|Williams|   3|         42|  +1:08.536|   4.0|       5|2024-04-26 07:44:...|
# |     2004|Australian Grand ...|     null|       Melbourne|     Ralf Schumacher|         null|            German|Williams|   8|         11|  +1:00.423|   5.0|       4|2024-04-26 07:44:...|
# |     2004|Australian Grand ...|     null|       Melbourne|  Michael Schumacher|         null|            German| Ferrari|   1|         29|1:24:15.757|  10.0|       1|2024-04-26 07:44:...|
