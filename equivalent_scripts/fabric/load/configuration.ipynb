# %% [markdown]
# ### Set variables for folder paths, which can be used in the ingestion notebooks.

# %%
bronze_folder_path = "Files/Formula1/bronze"
silver_folder_path = "Files/Formula1/silver"
gold_folder_path = "Files/Formula1/gold"
# Out:
# StatementMeta(, 88cf0399-771a-46ae-a4f2-c9f0202f10c4, 12, Finished, Available)

# %%
# For student account with less permissions.

# bronze_folder_path = 'abfss://1d143cdf-d6a0-4144-a19b-b23eccffe1d4@onelake.dfs.fabric.microsoft.com/1ff575d2-18d6-43cf-9b7d-21889a5c7c63/Files/Formula1/bronze'
# silver_folder_path = 'abfss://1d143cdf-d6a0-4144-a19b-b23eccffe1d4@onelake.dfs.fabric.microsoft.com/1ff575d2-18d6-43cf-9b7d-21889a5c7c63/Files/Formula1/silver'
# gold_folder_path = 'abfss://1d143cdf-d6a0-4144-a19b-b23eccffe1d4@onelake.dfs.fabric.microsoft.com/1ff575d2-18d6-43cf-9b7d-21889a5c7c63/Files/Formula1/gold'
