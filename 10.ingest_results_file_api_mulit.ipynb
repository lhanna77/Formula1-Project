# %% [markdown]
# ### Ingest qualifying json files

# %% [markdown]
# ##### Step 1 - Read the JSON file using the spark dataframe reader API

# %%
from pandas import read_csv,read_json,concat
from glob import glob
from lib import configuration
from lib import common_functions

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType

# %%
spark = common_functions.get_spark_session()

# %%
results_schema = StructType(fields=[StructField("resultId", IntegerType(), False),
                                    StructField("raceId", IntegerType(), True),
                                    StructField("driverId", IntegerType(), True),
                                    StructField("constructorId", IntegerType(), True),
                                    StructField("number", IntegerType(), True),
                                    StructField("grid", IntegerType(), True),
                                    StructField("position", IntegerType(), True),
                                    StructField("positionText", StringType(), True),
                                    StructField("positionOrder", IntegerType(), True),
                                    StructField("points", FloatType(), True),
                                    StructField("laps", IntegerType(), True),
                                    StructField("time", StringType(), True),
                                    StructField("milliseconds", IntegerType(), True),
                                    StructField("fastestLap", IntegerType(), True),
                                    StructField("rank", IntegerType(), True),
                                    StructField("fastestLapTime", StringType(), True),
                                    StructField("fastestLapSpeed", FloatType(), True),
                                    StructField("statusId", StringType(), True)])

# %%
folder_path = f"{configuration.api_folder_path}/results"
all_files = glob(folder_path + "/*.json")

dfs = [read_json(file, lines=True) for file in all_files]
results_df = concat(dfs, ignore_index=True)
results_df
# Out:
#        resultId                  raceId     driverId constructorId number  \
# 0             1  British Grand Prix1950       farina          alfa      2
# 1             2  British Grand Prix1950      fagioli          alfa      3
# 2             3  British Grand Prix1950  reg_parnell          alfa      4
# 3             4  British Grand Prix1950    cabantous          lago     14
# 4             5  British Grand Prix1950       rosier          lago     15
# ...         ...                     ...          ...           ...    ...
# 26434      9996    Dutch Grand Prix1984       piquet       brabham      1
# 26435      9997    Dutch Grand Prix1984     ghinzani        osella     24
# 26436      9998    Dutch Grand Prix1984     alboreto       ferrari     27
# 26437      9999  Italian Grand Prix1984        lauda       mclaren      8
# 26438     10000  Italian Grand Prix1984     alboreto       ferrari     27
#
#        grid  position positionText  positionOrder  points  laps      statusId
# 0         1         1            1  positionOrder     9.0    70      Finished
# 1         2         2            2  positionOrder     6.0    70      Finished
# 2         4         3            3  positionOrder     4.0    70      Finished
# 3         6         4            4  positionOrder     3.0    68       +2 Laps
# 4         9         5            5  positionOrder     2.0    68       +2 Laps
# ...     ...       ...          ...            ...     ...   ...           ...
# 26434     2        25            R  positionOrder     0.0    10  Oil pressure
# 26435    21        26            R  positionOrder     0.0     8     Fuel pump
# 26436     9        27            R  positionOrder     0.0     7        Engine
# 26437     4         1            1  positionOrder     9.0    51      Finished
# 26438    11         2            2  positionOrder     6.0    51      Finished
#
# [26439 rows x 12 columns]

# %% [markdown]
# ##### Step 2 - Rename columns and add new columns
# 1. Rename qualifyingId, driverId, constructorId and raceId
# 1. Add ingestion_date with current timestamp

# %%
results_df["data_source"] = configuration.v_data_source
results_df["ingestion_date"] = common_functions.get_ingestion_date()
results_df
# Out:
#        resultId                  raceId     driverId constructorId number  \
# 0             1  British Grand Prix1950       farina          alfa      2
# 1             2  British Grand Prix1950      fagioli          alfa      3
# 2             3  British Grand Prix1950  reg_parnell          alfa      4
# 3             4  British Grand Prix1950    cabantous          lago     14
# 4             5  British Grand Prix1950       rosier          lago     15
# ...         ...                     ...          ...           ...    ...
# 26434      9996    Dutch Grand Prix1984       piquet       brabham      1
# 26435      9997    Dutch Grand Prix1984     ghinzani        osella     24
# 26436      9998    Dutch Grand Prix1984     alboreto       ferrari     27
# 26437      9999  Italian Grand Prix1984        lauda       mclaren      8
# 26438     10000  Italian Grand Prix1984     alboreto       ferrari     27
#
#        grid  position positionText  positionOrder  points  laps      statusId  \
# 0         1         1            1  positionOrder     9.0    70      Finished
# 1         2         2            2  positionOrder     6.0    70      Finished
# 2         4         3            3  positionOrder     4.0    70      Finished
# 3         6         4            4  positionOrder     3.0    68       +2 Laps
# 4         9         5            5  positionOrder     2.0    68       +2 Laps
# ...     ...       ...          ...            ...     ...   ...           ...
# 26434     2        25            R  positionOrder     0.0    10  Oil pressure
# 26435    21        26            R  positionOrder     0.0     8     Fuel pump
# 26436     9        27            R  positionOrder     0.0     7        Engine
# 26437     4         1            1  positionOrder     9.0    51      Finished
# 26438    11         2            2  positionOrder     6.0    51      Finished
#
#       data_source ingestion_date
# 0             dev     2024-05-29
# 1             dev     2024-05-29
# 2             dev     2024-05-29
# 3             dev     2024-05-29
# 4             dev     2024-05-29
# ...           ...            ...
# 26434         dev     2024-05-29
# 26435         dev     2024-05-29
# 26436         dev     2024-05-29
# 26437         dev     2024-05-29
# 26438         dev     2024-05-29
#
# [26439 rows x 14 columns]

# %%
results_final_df = results_df.rename(columns={"resultId":"result_id","raceId":"race_id","driverId":"driver_id","constructorId":"constructor_id","positionText":"position_text","positionOrder":"position_order","statusId":"status"})
results_final_df
# Out:
#        result_id                 race_id    driver_id constructor_id number  \
# 0              1  British Grand Prix1950       farina           alfa      2
# 1              2  British Grand Prix1950      fagioli           alfa      3
# 2              3  British Grand Prix1950  reg_parnell           alfa      4
# 3              4  British Grand Prix1950    cabantous           lago     14
# 4              5  British Grand Prix1950       rosier           lago     15
# ...          ...                     ...          ...            ...    ...
# 26434       9996    Dutch Grand Prix1984       piquet        brabham      1
# 26435       9997    Dutch Grand Prix1984     ghinzani         osella     24
# 26436       9998    Dutch Grand Prix1984     alboreto        ferrari     27
# 26437       9999  Italian Grand Prix1984        lauda        mclaren      8
# 26438      10000  Italian Grand Prix1984     alboreto        ferrari     27
#
#        grid  position position_text position_order  points  laps  \
# 0         1         1             1  positionOrder     9.0    70
# 1         2         2             2  positionOrder     6.0    70
# 2         4         3             3  positionOrder     4.0    70
# 3         6         4             4  positionOrder     3.0    68
# 4         9         5             5  positionOrder     2.0    68
# ...     ...       ...           ...            ...     ...   ...
# 26434     2        25             R  positionOrder     0.0    10
# 26435    21        26             R  positionOrder     0.0     8
# 26436     9        27             R  positionOrder     0.0     7
# 26437     4         1             1  positionOrder     9.0    51
# 26438    11         2             2  positionOrder     6.0    51
#
#              status data_source ingestion_date
# 0          Finished         dev     2024-05-29
# 1          Finished         dev     2024-05-29
# 2          Finished         dev     2024-05-29
# 3           +2 Laps         dev     2024-05-29
# 4           +2 Laps         dev     2024-05-29
# ...             ...         ...            ...
# 26434  Oil pressure         dev     2024-05-29
# 26435     Fuel pump         dev     2024-05-29
# 26436        Engine         dev     2024-05-29
# 26437      Finished         dev     2024-05-29
# 26438      Finished         dev     2024-05-29
#
# [26439 rows x 14 columns]

# %% [markdown]
# ##### Step 3 - Write to output to processed container in parquet format

# %%
results_final_df.to_csv(f"{configuration.silver_api_folder_path}/results.csv", index=False)

# %%
df_parquet = read_csv(f'{configuration.silver_api_folder_path}/results.csv')
df_parquet
# Out:
#        result_id                 race_id    driver_id constructor_id  number  \
# 0              1  British Grand Prix1950       farina           alfa     2.0
# 1              2  British Grand Prix1950      fagioli           alfa     3.0
# 2              3  British Grand Prix1950  reg_parnell           alfa     4.0
# 3              4  British Grand Prix1950    cabantous           lago    14.0
# 4              5  British Grand Prix1950       rosier           lago    15.0
# ...          ...                     ...          ...            ...     ...
# 26434       9996    Dutch Grand Prix1984       piquet        brabham     1.0
# 26435       9997    Dutch Grand Prix1984     ghinzani         osella    24.0
# 26436       9998    Dutch Grand Prix1984     alboreto        ferrari    27.0
# 26437       9999  Italian Grand Prix1984        lauda        mclaren     8.0
# 26438      10000  Italian Grand Prix1984     alboreto        ferrari    27.0
#
#        grid  position position_text position_order  points  laps  \
# 0         1         1             1  positionOrder     9.0    70
# 1         2         2             2  positionOrder     6.0    70
# 2         4         3             3  positionOrder     4.0    70
# 3         6         4             4  positionOrder     3.0    68
# 4         9         5             5  positionOrder     2.0    68
# ...     ...       ...           ...            ...     ...   ...
# 26434     2        25             R  positionOrder     0.0    10
# 26435    21        26             R  positionOrder     0.0     8
# 26436     9        27             R  positionOrder     0.0     7
# 26437     4         1             1  positionOrder     9.0    51
# 26438    11         2             2  positionOrder     6.0    51
#
#              status data_source ingestion_date
# 0          Finished         dev     2024-05-29
# 1          Finished         dev     2024-05-29
# 2          Finished         dev     2024-05-29
# 3           +2 Laps         dev     2024-05-29
# 4           +2 Laps         dev     2024-05-29
# ...             ...         ...            ...
# 26434  Oil pressure         dev     2024-05-29
# 26435     Fuel pump         dev     2024-05-29
# 26436        Engine         dev     2024-05-29
# 26437      Finished         dev     2024-05-29
# 26438      Finished         dev     2024-05-29
#
# [26439 rows x 14 columns]
